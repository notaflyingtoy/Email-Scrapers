# %%
import requests
import openpyxl
import re
from openpyxl import load_workbook
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import csv
import pandas as pd

# %%
driver = webdriver.Chrome(executable_path= \
            r'C:\Users\safeh\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
#iterate over pages 1596 pages be aware of page 1596
#iterate

# %%
list_of_URLs = []
charities = []
charities_URLs = []
for i in range(1, 1596):
    list_of_URLs.append("https://www.charitychoice.co.uk/charities/london/{}?onlinedonations=0".format(i))
print(len(list_of_URLs))
print(list_of_URLs)
# Out:
# 1595
# ['https://www.charitychoice.co.uk/charities/london/1?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/2?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/3?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/4?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/5?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/6?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/7?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/8?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/9?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/10?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/11?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/12?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/13?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/14?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/15?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/16?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/17?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/18?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/19?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/20?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/21?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/22?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/23?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/24?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/25?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/26?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/27?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/28?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/29?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/30?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/31?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/32?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/33?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/34?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/35?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/36?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/37?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/38?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/39?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/40?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/41?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/42?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/43?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/44?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/45?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/46?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/47?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/48?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/49?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/50?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/51?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/52?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/53?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/54?onlinedonations=0', 'https://www.charitychoice.co.uk/charities/london/55?onlinedonatio ...

# %%
for URL in list_of_URLs:
    page = requests.get(URL).content
    souper = BeautifulSoup(page, 'html.parser')
    h2_list = souper.find_all("h2")[1:21]
    for href in h2_list:
        charities.append(href.text)
        charities_URLs.append("https://www.charitychoice.co.uk"+href.find("a")["href"])

# %%
print(len(charities))
print(len(listof))
#print(charities_URLs)
# Out:
# 31900
# 31900

# %%
count = 1
emails=[]
#print(charities_URLs)
#error at 17875
#errorat 27604

# %%
driver = webdriver.Chrome(executable_path= \
            r'C:\Users\safeh\Downloads\chromedriver_win32 (1)\chromedriver.exe') 
for charity_URL in listof[27604:31900]:
    #page = requests.get(charity_URL).content
    #soup_contact = BeautifulSoup(page, 'html.parser')
    #try:
     #   email_on_contact = soup_contact.find("p", text=re.compile("@")).text
    #except:
    #try:
    driver.get(charity_URL)
    #print(charity_URL)
    try:
        email_on_contact = driver.find_element_by_xpath('//a[contains(@href, "mailto")]').text
    except:
        email_on_contact="Not Found"
    #except:
     #   email_on_contact = "Not Found"
    emails.append(email_on_contact)
    print(count)
    count+=1
#driver.close()
#print(emails)
print(len(emails))
driver.close()
# Out:
# 1
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-109-e405ea7ac430> in <module>
#       8     #except:
#       9     #try:
# ---> 10     driver.get(charity_URL)
#      11     #print(charity_URL)
#      12     try:
#
# c:\users\safeh\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# c:\users\safeh\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# c:\users\safeh\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# c:\users\safeh\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# c:\users\safeh\appdata\local\programs\python\python37\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      78         else:
#      79             return self.request_encode_body(
# ---> 80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#      82
#
# c:\users\safeh\appdata\local\programs\python\python37\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# c:\users\safeh\appdata\local\programs\python\python37\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     328             response = conn.urlopen(method, url, **kw)
#     329         else:
# --> 330             response = conn.urlopen(method, u.request_uri, **kw)
#     331
#     332         redirect_location = redirect and response.get_redirect_location()
#
# c:\users\safeh\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# c:\users\safeh\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\users\safeh\appdata\local\programs\python\python37\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\safeh\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# c:\users\safeh\appdata\local\programs\python\python37\lib\http\client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# c:\users\safeh\appdata\local\programs\python\python37\lib\http\client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# c:\users\safeh\appdata\local\programs\python\python37\lib\http\client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# c:\users\safeh\appdata\local\programs\python\python37\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
print(len(emails))
# Out:
# 4296

# %%
wb = load_workbook('emails_found.xlsx')
sh=wb["Sheet3"]
#wb.save('emails.xlsx')

# %%
line = 1
for charity in charities:
    sh.cell(row=line, column=1, value=charity)
    line+=1
wb.save('emails_found.xlsx')

# %%
line = 1
col = 2
for email in emails:
    sh.cell(row=line, column=col, value=email)
    line+=1

wb.save('emails_found.xlsx')

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome(executable_path= \
            r'C:\Users\safeh\Downloads\chromedriver_win32 (1)\chromedriver.exe')
driver.get("https://www.charitychoice.co.uk/test1234")
#assert "Python" in driver.title
#elem = driver.find_element_by_xpath("//a[@href]").text()
elem = driver.find_element_by_xpath('//a[contains(@href, "mailto")]')
#elem.clear()
print(elem.text)
#elem.send_keys("pycon")
#elem.send_keys(Keys.RETURN)
#assert "No results found." not in driver.page_source

driver.close()
# Out:
# claudia@charitychoice.co.uk

# %%
print(emails)
# Out:
# []

# %%
df = pd.DataFrame(charities_URLs)

# %%
df.to_csv("charities_urls.csv")

# %%
charities_URLs = pd.read_csv("charities_urls.csv")

# %%
listof = charities_URLs["0"].tolist()

# %%
type(listof)
# Out:
# list
